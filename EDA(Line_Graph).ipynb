# %% [markdown]
# <a href="https://colab.research.google.com/github/disha2101/1Stop_Internship_Codes/blob/main/EDA(Line_Graph).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
#plotting a simple graph
#list-[]
#tuple-()
#dict-{}

# %%
squares = [0,1,4,9,16,25]
plt.plot(squares,linewidth=10)
plt.show()
#output is (0,0)(1,1)(2,4)(3,9)(4,16)(5,25)

# %%
plt.title("Square number",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Square of Values",fontsize=14)
plt.plot(squares)
plt.show()

# %%
plt.title("Square Numbers",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Square of Values",fontsize=14)
plt.plot(squares,dash_capstyle="round")
#set size of ticks 
plt.tick_params(axis="both",labelsize=12)
